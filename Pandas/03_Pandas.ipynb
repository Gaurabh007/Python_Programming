# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/titanic.csv')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df['Name'][2:11]
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %% [markdown]
# Converting a list into a Series and vice-versa

# %%
pd.Series(['a','b','c','d','e','f'])
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# dtype: object

# %%
list(df['Name'][2:11])
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry',
#  'Moran, Mr. James',
#  'McCarthy, Mr. Timothy J',
#  'Palsson, Master. Gosta Leonard',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Sandstrom, Miss. Marguerite Rut']

# %% [markdown]
# * When we want to make our own index it can be possible only with the list.

# %%
pd.Series(list(df['Name'][2:7]), index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# d                                Moran, Mr. James
# e                         McCarthy, Mr. Timothy J
# dtype: object

# %% [markdown]
# * In case of a Series it has it default index, if we override the indexes it will nullify the data.

# %%
pd.Series(df['Name'][2:7], index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# Name: Name, dtype: object

# %%
s = pd.Series(list(df['Name'][2:7]), index=['a', 'b', 'c', 'd', 'e'])

# %%
s1 = df['Name'][2:7]

# %% [markdown]
# * Now if we try to concatenate two series using '+' operator it will add the index will nullify the data

# %%
s+s1
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# dtype: object

# %% [markdown]
# * The solution to this problem is using .append() or .concat() method.

# %%
# s.append(s1)          #Alternative method to concatenating two series

sf = pd.concat([s,s1])

# %%
sf
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# d                                Moran, Mr. James
# e                         McCarthy, Mr. Timothy J
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# 6                         McCarthy, Mr. Timothy J
# dtype: object

# %% [markdown]
# # Column Operation
# ### Deleting columns from the dataset

# %%
# .drop() method does'nt permanently deletes the column, it removes it for a particular execution. 
# axis = 0 --> Rows
# axis = 1 --> Columns
df.drop('PassengerId',axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.head(3)      #As we can see the passengerId is not deleted
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# To permanently delete the column we use another parameter i.e., inplace = True
df.drop('PassengerId',axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# # Row Operation
# ### Deleting Rows from the dataset

# %%
df.drop(3,inplace=True)     #3rd index will be deleted permanently

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# #### Setting any other column as the index

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %% [markdown]
# ### Fetching a row based on the new Index

# %%
rec_detail = df.loc['Heikkinen, Miss. Laina']

# %%
rec_detail      #details of a particular row
# Out:
# Survived                   1
# Pclass                     3
# Sex                   female
# Age                     26.0
# SibSp                      0
# Parch                      0
# Ticket      STON/O2. 3101282
# Fare                   7.925
# Cabin                    NaN
# Embarked                   S
# Name: Heikkinen, Miss. Laina, dtype: object

# %% [markdown]
# Getting back all the indices of the dataset.(Reset)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ### Conversion of a dictionary to DataFrame

# %%
d = {
    'key1': [1, 5, 9],          #all the values must have same length
    'key2': [7, 5, 3],
    'key3': [2, 5, 8]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     7     2
# 1     5     5     5
# 2     9     3     8

# %%
d1 = {
    'key1': (1, 5, 9),          #all the values must have same length
    'key2': (7, 5, 3),
    'key3': (2, 5, 8)
}

# %%
pd.DataFrame(d1)
# Out:
#    key1  key2  key3
# 0     1     7     2
# 1     5     5     5
# 2     9     3     8

# %% [markdown]
# ## Working with Missing Values or NaN

# %%
dff = pd.read_csv('dataset/taxonomy.xls')

# %%
dff
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %% [markdown]
# Dropping all the rows having NaN values.By default this operation is performed on rows.

# %%
dff.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %% [markdown]
# * Now checking column wise.

# %%
dff.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %% [markdown]
# * Filling all the NaN values with custom values like NULL.

# %%
dff.fillna('NULL',inplace=True)

# %%
dff
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency      NULL                  NULL
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %% [markdown]
# * Grouping the 'survived' column with its categorical data

# %%
# Split the data based on survived and death
df.groupby('Survived').mean()
# Out:
# C:\Users\Gaurabh Chowdhury\AppData\Local\Temp\ipykernel_4936\130121650.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.320657  0.472141  0.466276  48.381611

# %%
# Total fare paid by those ppl who have died and who have survived
df.groupby('Survived').sum()
# Out:
# C:\Users\Gaurabh Chowdhury\AppData\Local\Temp\ipykernel_4936\1666341004.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8184.67    161    159  16498.1294

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Grouping based on Sex
df.groupby('Sex').sum()
# Out:
# C:\Users\Gaurabh Chowdhury\AppData\Local\Temp\ipykernel_4936\1604522719.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').sum()
#         Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       232     677   7251.00    217    204  13913.5628
# male         109    1379  13919.17    248    136  14727.2865

# %%
# Average age of male and female
df.groupby('Sex').mean()['Age']
# Out:
# C:\Users\Gaurabh Chowdhury\AppData\Local\Temp\ipykernel_4936\1420217422.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').mean()['Age']
# Sex
# female    27.888462
# male      30.726645
# Name: Age, dtype: float64

# %%
# Information based on Passenger Class
df.groupby('Pclass').sum()
# Out:
# C:\Users\Gaurabh Chowdhury\AppData\Local\Temp\ipykernel_4936\1127486015.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Pclass').sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7076.42     89     77  18124.3125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
asdf = df.groupby('Pclass').sum()
# Out:
# C:\Users\Gaurabh Chowdhury\AppData\Local\Temp\ipykernel_4936\3154327814.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   asdf = df.groupby('Pclass').sum()

# %%
for i in asdf:
    if i == 'Survived':
        print(asdf[i])
# Out:
# Pclass
# 1    135
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %% [markdown]
# * #### Transpose Operation

# %%
asdf.T      #The whole dataframe is rotated (All the rows are converted to column and vice-versa)
# Out:
# Pclass             1          2          3
# Survived    135.0000    87.0000   119.0000
# Age        7076.4200  5168.8300  8924.9200
# SibSp        89.0000    74.0000   302.0000
# Parch        77.0000    70.0000   193.0000
# Fare      18124.3125  3801.8417  6714.6951

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df11 = df[['Name','Survived','Pclass']][0:5]

# %%
df12 = df[['Name','Survived','Pclass']][5:11]

# %%
df11
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df12
# Out:
#                                                  Name  Survived  Pclass
# 5                             McCarthy, Mr. Timothy J         0       1
# 6                      Palsson, Master. Gosta Leonard         0       3
# 7   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                 Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                     Sandstrom, Miss. Marguerite Rut         1       3
# 10                           Bonnell, Miss. Elizabeth         1       1

# %%
# Horizontal concatenating df11 and df12

pd.concat([df11,df12])
# Out:
#                                                  Name  Survived  Pclass
# 0                             Braund, Mr. Owen Harris         0       3
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                              Heikkinen, Miss. Laina         1       3
# 3                            Allen, Mr. William Henry         0       3
# 4                                    Moran, Mr. James         0       3
# 5                             McCarthy, Mr. Timothy J         0       1
# 6                      Palsson, Master. Gosta Leonard         0       3
# 7   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                 Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                     Sandstrom, Miss. Marguerite Rut         1       3
# 10                           Bonnell, Miss. Elizabeth         1       1

# %%
# Vertical concatenation between df11 and df12

pd.concat([df11,df12],axis=1)
# Out:
#                                                  Name  Survived  Pclass  \
# 0                             Braund, Mr. Owen Harris       0.0     3.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                              Heikkinen, Miss. Laina       1.0     3.0
# 3                            Allen, Mr. William Henry       0.0     3.0
# 4                                    Moran, Mr. James       0.0     3.0
# 5                                                 NaN       NaN     NaN
# 6                                                 NaN       NaN     NaN
# 7                                                 NaN       NaN     NaN
# 8                                                 NaN       NaN     NaN
# 9                                                 NaN       NaN     NaN
# 10                                                NaN       NaN     NaN
#
#                                                  Name  Survived  Pclass
# ...

# %% [markdown]
# ### Merging two DataFrame

# %%
d1 = pd.DataFrame({
    'Key 1':[1,5,9],
    'Key 2':[7,3,5],
    'Key 3':[7,9,5]
})
d1
# Out:
#    Key 1  Key 2  Key 3
# 0      1      7      7
# 1      5      3      9
# 2      9      5      5

# %%
d2 = pd.DataFrame({
    'Key 1':[1,6,9],
    'Key 4':[46,58,7],
    'Key 5':[6,54,32]
})
d2
# Out:
#    Key 1  Key 4  Key 5
# 0      1     46      6
# 1      6     58     54
# 2      9      7     32

# %% [markdown]
# The merge is done on the basis of that one common column present on both the dataframe.Then it will check the data in that common column and only those data will be taken which is common in both of the dataframe

# %%
pd.merge(d1,d2)
# Out:
#    Key 1  Key 2  Key 3  Key 4  Key 5
# 0      1      7      7     46      6
# 1      9      5      5      7     32

# %%
pd.merge(d1,d2,how='left')
# Out:
#    Key 1  Key 2  Key 3  Key 4  Key 5
# 0      1      7      7   46.0    6.0
# 1      5      3      9    NaN    NaN
# 2      9      5      5    7.0   32.0

# %%
pd.merge(d1, d2, how='outer')   #union of both the dataframe
# Out:
#    Key 1  Key 2  Key 3  Key 4  Key 5
# 0      1    7.0    7.0   46.0    6.0
# 1      5    3.0    9.0    NaN    NaN
# 2      9    5.0    5.0    7.0   32.0
# 3      6    NaN    NaN   58.0   54.0

# %%
pd.merge(d1,d2,how='cross')     #it performs a cartesian product on both dataframe
# Out:
#    Key 1_x  Key 2  Key 3  Key 1_y  Key 4  Key 5
# 0        1      7      7        1     46      6
# 1        1      7      7        6     58     54
# 2        1      7      7        9      7     32
# 3        5      3      9        1     46      6
# 4        5      3      9        6     58     54
# 5        5      3      9        9      7     32
# 6        9      5      5        1     46      6
# 7        9      5      5        6     58     54
# 8        9      5      5        9      7     32

# %% [markdown]
# ### Joining Two DataFrame

# %%
data1 = pd.DataFrame({
    'key1': [1, 2, 4, 5, 6],
    'key2': [4, 5, 6, 7, 8],
    'key3': [3, 4, 5, 6, 6]},
    index=['a', 'b', 'c', 'd', 'e']
)
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
data2 = pd.DataFrame(
    {'key11': [1, 2, 4, 5, 6],
    'key22': [4, 5, 6, 7, 8],
    'key33': [3, 4, 5, 6, 6]},
    index=['a', 'b', 'h', 'i', 'j']
)
data2
# Out:
#    key11  key22  key33
# a      1      4      3
# b      2      5      4
# h      4      6      5
# i      5      7      6
# j      6      8      6

# %% [markdown]
# The join operation is based on the rows index. For a common row in 'data1' it is joined with 'data2'.

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3      1      4      3
# b     2     5     4      2      5      4

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0    1.0    4.0    3.0
# b   2.0   5.0   4.0    2.0    5.0    4.0
# c   4.0   6.0   5.0    NaN    NaN    NaN
# d   5.0   7.0   6.0    NaN    NaN    NaN
# e   6.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    4.0    6.0    5.0
# i   NaN   NaN   NaN    5.0    7.0    6.0
# j   NaN   NaN   NaN    6.0    8.0    6.0

# %%
# Creating a new column where the fare is stored in INR.
df['Fare(INR)'] = df['Fare'].apply(lambda i : i*80)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare(INR)
# 0    580.000
# 1   5702.664
# 2    634.000
# 3    644.000
# 4    676.664

# %%
# Check the length of each name
df['Name_len'] = df['Name'].apply(lambda i : len(i))

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare(INR)  Name_len
# 0    580.000        23
# 1   5702.664        51
# 2    634.000        22
# ...

# %%
# Classify Fare column based on [Class1,Class2,Class3]
def fare_class(i):
    if i <= 10:
        return 'Class3'
    elif i > 10 and i < 20:
        return 'Class2'
    else:
        return 'Class1'


df['flag_fare'] = df['Fare'].apply(fare_class)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare(INR)  Name_len flag_fare
# 0    580.000        23    Class3
# 1   5702.664        51    Class1
# ...

# %%
df.groupby('flag_fare').sum()
# Out:
# C:\Users\Gaurabh Chowdhury\AppData\Local\Temp\ipykernel_4936\1799674267.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('flag_fare').sum()
#            Survived  Pclass       Age  SibSp  Parch        Fare    Fare(INR)  \
# flag_fare
# Class1          198     627  10217.25    370    277  23631.3791  1890510.328
# Class2           76     439   4308.00     68     53   2484.4499   198755.992
# Class3           67     990   6644.92     27     10   2525.0203   202001.624
#
#            Name_len
# flag_fare
# Class1        11219
# Class2         4928
# Class3         7835
