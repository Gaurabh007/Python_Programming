# %%
import pandas as pd

# %% [markdown]
# Reading  data form a csv (comma seperated values) file

# %%
df = pd.read_csv('dataset/Iris.csv')

# %% [markdown]
# ### If we want to make the column header as data we use the header attribute

# %%
data1 = pd.read_csv('dataset/Iris.csv',header=None)

# %%
data1
# Out:
#        0              1             2              3             4  \
# 0     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1      1            5.1           3.5            1.4           0.2
# 2      2            4.9           3.0            1.4           0.2
# 3      3            4.7           3.2            1.3           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 146  146            6.7           3.0            5.2           2.3
# 147  147            6.3           2.5            5.0           1.9
# 148  148            6.5           3.0            5.2           2.0
# 149  149            6.2           3.4            5.4           2.3
# 150  150            5.9           3.0            5.1           1.8
#
#                   5
# 0           Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Column Selection

# %%
# Checking all the columns
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Id',
#  'SepalLengthCm',
#  'SepalWidthCm',
#  'PetalLengthCm',
#  'PetalWidthCm',
#  'Species']

# %% [markdown]
# ### To get a number of record from the beginning we use .head() function

# %%
df.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# ### To get a number of record from the end we use .tail() function

# %%
df.tail(4)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# ### Knowing the datatype of the data

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# ### Selecting a specific column

# %%
df['Species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %% [markdown]
# * If we check the type of a particular column it shows that it is a Series
# * When we pass a column name as String it takes it as a Series

# %%
type(df['Species'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# We can able to convert the series to a list.

# %%
list(df['Species'])
# Out:
# ['Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor',
# ...

# %%
df[['Species']]
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %% [markdown]
# Now if we check the datatype it will be Dataframe

# %%
type(df[['Species']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### When we required to pass multiple column we have to pass it within a list

# %%
df[['SepalLengthCm','Species']]
# Out:
#      SepalLengthCm         Species
# 0              5.1     Iris-setosa
# 1              4.9     Iris-setosa
# 2              4.7     Iris-setosa
# 3              4.6     Iris-setosa
# 4              5.0     Iris-setosa
# ..             ...             ...
# 145            6.7  Iris-virginica
# 146            6.3  Iris-virginica
# 147            6.5  Iris-virginica
# 148            6.2  Iris-virginica
# 149            5.9  Iris-virginica
#
# [150 rows x 2 columns]

# %% [markdown]
# #### Reading data from excel sheets

# %%
df1 = pd.read_excel('dataset/Salaries.xlsx')

# %%
df1
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       67    Private  366425     Doctorate               16
# 1       17    Private  244602          12th                8
# 2       31    Private  174201     Bachelors               13
# 3       58  State-gov  110199       7th-8th                4
# 4       25  State-gov  149248  Some-college               10
# ...    ...        ...     ...           ...              ...
# 43952   52    Private   68982     Bachelors               13
# 43953   19    Private  116562       HS-grad                9
# 43954   30    Private  197947  Some-college               10
# 43955   46    Private   97883     Bachelors               13
# 43956   30    Private  375827       HS-grad                9
#
#            marital-status         occupation    relationship   race  gender  \
# 0                Divorced    Exec-managerial   Not-in-family  White    Male
# 1           Never-married      Other-service       Own-child  White    Male
# ...

# %%
df1.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income_>50K'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income_>50K         int64
# dtype: object

# %%
df1['education']
# Out:
# 0           Doctorate
# 1                12th
# 2           Bachelors
# 3             7th-8th
# 4        Some-college
#              ...
# 43952       Bachelors
# 43953         HS-grad
# 43954    Some-college
# 43955       Bachelors
# 43956         HS-grad
# Name: education, Length: 43957, dtype: object

# %%
type(df1['education'])
# Out:
# pandas.core.series.Series

# %%
type(df1[['education']])
# Out:
# pandas.core.frame.DataFrame

# %%
df1[['marital-status', 'occupation', 'relationship']]
# Out:
#            marital-status         occupation    relationship
# 0                Divorced    Exec-managerial   Not-in-family
# 1           Never-married      Other-service       Own-child
# 2      Married-civ-spouse    Exec-managerial         Husband
# 3      Married-civ-spouse   Transport-moving         Husband
# 4           Never-married      Other-service   Not-in-family
# ...                   ...                ...             ...
# 43952  Married-civ-spouse    Exec-managerial         Husband
# 43953       Never-married      Other-service       Own-child
# 43954            Divorced              Sales   Not-in-family
# 43955       Never-married              Sales   Not-in-family
# 43956       Never-married  Handlers-cleaners  Other-relative
#
# [43957 rows x 3 columns]

# %%
df1[['marital-status', 'occupation', 'relationship']]
# Out:
#            marital-status         occupation    relationship
# 0                Divorced    Exec-managerial   Not-in-family
# 1           Never-married      Other-service       Own-child
# 2      Married-civ-spouse    Exec-managerial         Husband
# 3      Married-civ-spouse   Transport-moving         Husband
# 4           Never-married      Other-service   Not-in-family
# ...                   ...                ...             ...
# 43952  Married-civ-spouse    Exec-managerial         Husband
# 43953       Never-married      Other-service       Own-child
# 43954            Divorced              Sales   Not-in-family
# 43955       Never-married              Sales   Not-in-family
# 43956       Never-married  Handlers-cleaners  Other-relative
#
# [43957 rows x 3 columns]

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# To download the data into your local system

# %%
df2.to_csv("dataset/titanic.csv")

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# When we want to remove the index from the data.

# %%
df2.to_csv("dataset/titanic.csv",index=False)

# %% [markdown]
# #### Reading only the tabular data from a web page

# %%
import lxml
import pandas as pd

url_data = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(url_data)      #Therefore it stores the data in a list so the length will be 1
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
url_data[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
url = url_data[0]
type(url)               #Now if we check the datatype it will be Dataframe, which means now we can perform all the operation as we have done with the previous dataframes.
# Out:
# pandas.core.frame.DataFrame

# %%
url.tail(3)         #Checking the last three row
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
url.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
url[['Player', 'Pos', 'Age']]
# Out:
#              Player Pos Age
# 0        Quincy Acy  PF  24
# 1      Jordan Adams  SG  20
# 2      Steven Adams   C  21
# 3       Jeff Adrien  PF  28
# 4     Arron Afflalo  SG  29
# ..              ...  ..  ..
# 670  Thaddeus Young  PF  26
# 671  Thaddeus Young  PF  26
# 672  Thaddeus Young  PF  26
# 673     Cody Zeller   C  22
# 674    Tyler Zeller   C  25
#
# [675 rows x 3 columns]

# %% [markdown]
# Saving the Data into my Local System

# %%
url.to_excel('dataset/players.xlsx',index=False)        #Removing the index from the dataset and saving it
